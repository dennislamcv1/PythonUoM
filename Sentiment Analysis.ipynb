# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resulting_data.csv")

# %%
df
# Out:
#     NumberofRetweets   Number of Replies   Positive Score   Negative Score  \
# 0                  3                   0                0                0
# 1                  1                   0                2                2
# 2                  1                   2                0                0
# 3                  3                   1                1                0
# 4                  6                   0                2                0
# 5                  9                   5                2                0
# 6                 19                   0                2                0
# 7                  0                   0                0                3
# 8                  0                   0                0                2
# 9                 82                   2                2                0
# 10                 0                   0                0                1
# ...

# %%
sns.scatterplot(x=df.NetScore , y=df.NumberofRetweets, data=df)
plt.title("Number of Retweets vs the Net Score", fontsize=12)
plt.show()
